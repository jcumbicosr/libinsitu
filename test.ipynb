# %%
# %load_ext autoreload
# %autoreload 2
from lib.handlers.enerMENA import *
from lib.log import error
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
handler = EnerMENAHandler()

# %%
res = handler.read_chunk("data/enerMENA/enerMENA-Jor_2017-10-01--2018-01-01.txt")

# %%
res
# Out:
#                      GHI  DIR  DIF      T2     RH        P
# 0
# 2017-09-30 22:01:00  0.0  0.0  0.0  289.45  0.588  90340.0
# 2017-09-30 22:02:00  0.0  0.0  0.0  289.45  0.589  90340.0
# 2017-09-30 22:03:00  0.0  0.0  0.0  289.35  0.590  90340.0
# 2017-09-30 22:04:00  0.0  0.0  0.0  289.35  0.592  90340.0
# 2017-09-30 22:05:00  0.0  0.0  0.0  289.25  0.596  90340.0
# ...                  ...  ...  ...     ...    ...      ...
# 2017-12-31 21:56:00  0.0  0.0  0.0  279.35  0.663  89980.0
# 2017-12-31 21:57:00  0.0  0.0  0.0  279.25  0.660  89980.0
# 2017-12-31 21:58:00  0.0  0.0  0.0  279.05  0.662  89980.0
# 2017-12-31 21:59:00  0.0  0.0  0.0  279.05  0.670  89980.0
# 2017-12-31 22:00:00  0.0  0.0  0.0  278.95  0.669  89980.0
#
# [91291 rows x 6 columns]

# %%
res.dtypes
# Out:
# ghi         float64
# dni         float64
# dhi         float64
# t_air       float64
# rh          float64
# bp          float64
# ws          float64
# wd          float64
# ws_gust     float64
# Cleaning      int64
# flag23        int64
# flag24        int64
# flag25        int64
# flag26        int64
# flag27        int64
# flag28        int64
# flag29        int64
# dtype: object
