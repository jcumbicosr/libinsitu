# %%
from brsn_reader import *
import datetime

# %%
# %time df, metadata = read_bsrn("data/bud0721.dat.gz")
print(metadata)
df
# Out:
# CPU times: user 1.31 s, sys: 33.7 ms, total: 1.34 s
# Wall time: 1.34 s
# {'start date': Timestamp('2021-07-01 00:00:00+0000', tz='UTC'), 'station identification number': 14, 'version of data': 1, 'date when station description changed': '-1 -1 -1', 'surface type': 15, 'topography type': 2, 'address': 'Hungarian Meteorological Service, Gilice ter 39, Budapest, Hungary', 'telephone no. of station': '+361 346 4840', 'FAX no. of station': 'XXX', 'TCP/IP no. of station': 'XXX', 'e-mail address of station': 'fekete.d@met.hu', 'latitude_bsrn': 137.429, 'latitude': 47.429, 'longitude_bsrn': 199.182, 'longitude': 19.181999999999988, 'altitude': 139, 'identification of "SYNOP" station': '12843', 'date when horizon changed': '-1 -1 -1', 'horizon': Series([], Name: horizon_elevation, dtype: int64)}
#                            ghi  ghi_std  ghi_min  ghi_max  dni  dni_std  \
# 2021-07-01 00:00:00+00:00   -1      0.0       -1       -1   -1      0.0
# ...

# %%
# Out:
#   File "/tmp/ipykernel_9158/2878580333.py", line 1
#     df[["ghi", "dhi"]]tzinfo
#                       ^
# SyntaxError: invalid syntax

# %%
start = datetime.datetime.strptime("2020-01-01", '%Y-%m-%d')
start64 = np.datetime64(start)

# %%
print(start.tzname())
# Out:
# None

# %%
df.index
# Out:
# array(['2021-07-01T00:00:00.000000000', '2021-07-01T00:01:00.000000000',
#        '2021-07-01T00:02:00.000000000', ...,
#        '2021-07-31T23:57:00.000000000', '2021-07-31T23:58:00.000000000',
#        '2021-07-31T23:59:00.000000000'], dtype='datetime64[ns]')

# %%
(df.index.values - start64) / 1000000000
# Out:
# array([47260800, 47260860, 47260920, ..., 49939020, 49939080, 49939140],
#       dtype='timedelta64[ns]')

# %%
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)
